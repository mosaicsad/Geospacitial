# %%
import cv2
import skimage.io as io
from skimage import data_dir
str='/Users/gaoyunfei/study/geospatial/sample_drive/cam_0' + '/*.jpg'
coll = io.ImageCollection(str)
#mat=io.concatenate_images(coll)
print (len(coll))
# Out:
# 4240

# %%
import numpy as np

# %%
for i in range(2):      #循环次数自己选择
    image=cv2.imread('/Users/gaoyunfei/study/geospatial/sample_drive/cam_0/%d.jpg'%(i))
    imshow(image)
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-4-97fc4259a514> in <module>()
#       7 str=data_dir+'/*.png'
#       8 coll = io.ImageCollection(str,load_func=convert_gray)
# ----> 9 io.imshow(coll[10])
#
# /Users/gaoyunfei/anaconda2/envs/py27/lib/python2.7/site-packages/skimage/io/_io.pyc in imshow(arr, plugin, **plugin_args)
#     154     if isinstance(arr, six.string_types):
#     155         arr = call_plugin('imread', arr, plugin=plugin)
# --> 156     return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#     157
#     158
#
# /Users/gaoyunfei/anaconda2/envs/py27/lib/python2.7/site-packages/skimage/io/manage_plugins.pyc in call_plugin(kind, *args, **kwargs)
#     209                                (plugin, kind))
#     210
# --> 211     return func(*args, **kwargs)
#     212
#     213
#
# /Users/gaoyunfei/anaconda2/envs/py27/lib/python2.7/site-packages/skimage/io/_plugins/matplotlib_plugin.pyc in imshow(im, ax, show_cbar, **kwargs)
# ...
